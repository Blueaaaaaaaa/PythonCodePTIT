# %%
#Bài 1 cách 1
# 1.Đọc file flights.csv và in ra số dòng, số cột của file
import csv
with open('iris.csv', 'r') as file:
    content = csv.reader(file) # Nhớ là reader không phải read
    data = [row for row in content] #
# data
# Out:
# 5
# 13

# %%
with open('file.csv', 'r') as file:
    lines = file.readlines()

for item in lines[1:]:
    split_item = item.split(',')
    if split_item[3] >"20.0" and split_item[2] == "male":
        print(split_item[3])
# Out:
# 22.0
# 35.0
# 54.0

# %%
data["flights"]
# Out:
# [{'year': '1949', 'month': 'January', 'passengers': '112'},
#  {'year': '1949', 'month': 'February', 'passengers': '118'},
#  {'year': '1949', 'month': 'March', 'passengers': '132'},
#  {'year': '1949', 'month': 'April', 'passengers': '102'},
#  {'year': '1945', 'month': 'May', 'passengers': '129'},
#  {'year': '1949', 'month': 'June', 'passengers': '144'},
#  {'year': '1949', 'month': 'July', 'passengers': '128'},
#  {'year': '1945', 'month': 'August', 'passengers': '138'},
#  {'year': '1945', 'month': 'September', 'passengers': '132'},
#  {'year': '1949', 'month': 'October', 'passengers': '126'},
#  {'year': '1949', 'month': 'November', 'passengers': '136'},
#  {'year': '1949', 'month': 'December', 'passengers': '144'}]

# %%
import json
with open("file.json", "r") as file:
    data = json.load(file)
# data["flights"][2]["passengers"]

for item in data["flights"]:
    if item["month"][-3:] == "ber":
        print(item["month"])
        print(item["year"])
        print(item["passengers"])
# Out:
# September
# 1945
# 132
# October
# 1949
# 126
# November
# 1949
# 136
# December
# 1949
# 144

# %%
#Bài 2
# 2.File json với định dạng đã cho. In ra giá trị của max và mean, cách nhau bởi dấu trắng

import json
with open('file.json', 'r') as file:
    data = json.load(file)
data["flights"]
maxn, minn = -10**9, 10**9
for content in data["flights"]:
    maxn = max(maxn, int(content["passengers"]))
    minn = min(minn, int(content["passengers"]))
print(maxn, minn)
# Out:
# 132 112

# %%
#Bài 3
#3.in ra số dòng và số cột của file json filght

import json
with open('file.json', 'r') as file:
    data = json.load(file)
data["flights"]
print(len(data["flights"]))
print(len(data["flights"][0]))
# Out:
# 3
# 3

# %%
import json

with open('file.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'flights': [{'year': '1949', 'month': 'January', 'passengers': '112'},
#   {'year': '1949', 'month': 'February', 'passengers': '118'},
#   {'year': '1949', 'month': 'March', 'passengers': '132'}]}

# %%
data["flights"][0]['year']
# Out:
# '1949'

# %%
maxn = -10**9
minn = 10**9
for i in range(len(data["flights"])):
    minn = min(minn, int(data["flights"][i]["passengers"]))
    maxn = max(maxn, int(data["flights"][i]["passengers"]))

# %%
print(maxn, minn)
# Out:
# 132 112

# %%
Ca 1:
    
Câu 1: Xử lý string (Siêu dễ)
Câu 2: Array (Dễ)
Câu 3: Class (Dễ)
Câu 4: Class (2 Class, 1 class để input , 1 class để xử lý ) *Note: phải nhớ format
Câu 5: Json

Ca 2:
Câu 1: String
Câu 2: https://code.ptit.edu.vn/student/question/PY01014
Câu 3: Dict
Câu 4: Class *Note: phải nhớ format
Câu 5: CSV
